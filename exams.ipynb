# %%
import pandas as pd
exams = pd.read_excel('exams.xlsx')
exams 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
exams. info
# Out:
# <bound method DataFrame.info of      gender race/ethnicity parental level of education         lunch  \
# 0    female        group D                some college      standard
# 1      male        group D          associate's degree      standard
# 2    female        group D                some college  free/reduced
# 3      male        group B                some college  free/reduced
# 4    female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                some college      standard
# 996    male        group C                some college      standard
# 997  female        group A                 high school      standard
# 998    male        group E                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
exams.head ()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          59             70             78
# 1                    none          96             93             87
# 2                    none          57             76             77
# 3                    none          70             70             63
# 4                    none          83             85             86

# %%
exams.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     67.810000      70.382000      69.140000
# std      15.250196      14.107413      15.025917
# min      15.000000      25.000000      15.000000
# 25%      58.000000      61.000000      59.000000
# 50%      68.000000      70.500000      70.000000
# 75%      79.250000      80.000000      80.000000
# max     100.000000     100.000000     100.000000

# %%
for i in range(1,exams.shape[1]-3):
    print(exams.columns[i])
    print(exams[exams.columns[i]].value_counts())
    print()
# Out:
# race/ethnicity
# group C    323
# group D    257
# group B    198
# group E    143
# group A     79
# Name: race/ethnicity, dtype: int64
#
# parental level of education
# some college          224
# high school           215
# associate's degree    204
# some high school      177
# bachelor's degree     105
# master's degree        75
# Name: parental level of education, dtype: int64
#
# lunch
# standard        660
# free/reduced    340
# Name: lunch, dtype: int64
#
# test preparation course
# none         656
# completed    344
# Name: test preparation course, dtype: int64

# %%
exams[['math score','reading score']].head()
# Out:
#    math score  reading score
# 0          59             70
# 1          96             93
# 2          57             76
# 3          70             70
# 4          83             85

# %%
exams.plot.scatter(x='math score',y='reading score')
plt.show()

# %%
exams['math score'].min()
# Out:
# 15

# %%
# parametros de la recta
w = 0.89
b = 0.36

# %%
# puntos de la recta
x = np.linspace(0,exams['math score'].max(),120)
y = w*x+b

# grafica de la recta
exams.plot.scatter(x='math score',y='reading score')
plt.plot(x, y, '-r')
plt.ylim(0,exams['reading score'].max()*1.1)
# plt.grid()
plt.show()
